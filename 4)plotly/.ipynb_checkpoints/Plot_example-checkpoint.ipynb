# %% [markdown]
# # Import Libraries

# %%
# import
import requests
import datetime
from datetime import datetime
from pandas import DataFrame
import json
import calendar

import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go
tls.set_credentials_file(username='TPponmat', api_key='Soc6snGEewzHbsvgaK8R')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %%
from pandas import DataFrame

# %% [markdown]
# # checkout data

# %% [markdown]
# ### 2. Inverter ###

# %%
inverter_data = pd.read_excel("SD1740L010 - 2018-02-20.xls", parse_dates = True, index_col = 0)
inverter_data.head(5)
# Out:
#                                       Time  Status  Vpv1(V)  Ipv1(A)  Ppv1(W)  \
# Alias / Serial number
# SD1740L010             2018-02-20 00:00:33  NORMAL     11.1      0.0        0
# SD1740L010             2018-02-20 00:05:33  NORMAL     11.1      0.0        0
# SD1740L010             2018-02-20 00:10:33  NORMAL     11.1      0.0        0
# SD1740L010             2018-02-20 00:15:33  NORMAL     11.1      0.0        0
# SD1740L010             2018-02-20 00:20:33  NORMAL     10.8      0.0        0
#
#                        Vpv2(V)  Ipv2(A)  Ppv2(W)  Ppv(W)  Vac(R)(V)  ...  \
# Alias / Serial number                                                ...
# SD1740L010                15.0      0.0        0       0      235.5  ...
# SD1740L010                15.0      0.0        0       0      237.1  ...
# SD1740L010                15.0      0.0        0       0      237.5  ...
# SD1740L010                15.1      0.0        0       0      239.1  ...
# SD1740L010                14.7      0.0        0       0      231.9  ...
#
#                        Eac_total(kWh)  T_total(H)  Bat_Volt(V)  Bat_Power(W)  \
# Alias / Serial number
# SD1740L010                      328.7         590         52.6            68
# SD1740L010                      328.8         590         52.6            82
# SD1740L010                      328.8         590         52.6            77
# SD1740L010                      328.8         590         52.6            80
# SD1740L010                      328.8         590         52.5           164
#
#                        Output_Volt(V)  Output_Freq(Hz)  Load_Power(W)  \
# Alias / Serial number
# SD1740L010                      231.3             50.0             67
# SD1740L010                      232.8             50.0             71
# SD1740L010                      233.3             50.0             48
# SD1740L010                      234.8             50.0             52
# SD1740L010                      227.7             50.0            170
#
#                        CHG_Temperature(℃)  Bat_Temperature(℃)  Bat_Percent(%)
# Alias / Serial number
# SD1740L010                           37.3                  30              54
# SD1740L010                           37.1                  30              54
# SD1740L010                           37.2                  30              54
# SD1740L010                           37.2                  30              54
# SD1740L010                           37.2                  30              54
#
# [5 rows x 32 columns]

# %%
inverter_data.columns
# Out:
# Index(['Time', 'Status', 'Vpv1(V)', 'Ipv1(A)', 'Ppv1(W)', 'Vpv2(V)', 'Ipv2(A)',
#        'Ppv2(W)', 'Ppv(W)', 'Vac(R)(V)', 'VacS(V)', 'VacT(V)', 'Iac(R)(A)',
#        'IacS(A)', 'IacT(A)', 'Fac(Hz)', 'Pac(W)', 'PacR(W)', 'PacS(W)',
#        'PacT(W)', 'Temperature(℃)', 'Eac_today(kWh)', 'Eac_total(kWh)',
#        'T_total(H)', 'Bat_Volt(V)', 'Bat_Power(W)', 'Output_Volt(V)',
#        'Output_Freq(Hz)', 'Load_Power(W)', 'CHG_Temperature(℃)',
#        'Bat_Temperature(℃)', 'Bat_Percent(%)'],
#       dtype='object')

# %%
inverter_data.describe()
# Out:
#           Vpv1(V)     Ipv1(A)      Ppv1(W)     Vpv2(V)     Ipv2(A)  \
# count  259.000000  259.000000   259.000000  259.000000  259.000000
# mean   135.792664    1.014286   283.899614  143.735907    0.511969
# std    135.263545    1.765559   475.549684  138.801643    1.128477
# min     10.500000    0.000000     0.000000   14.100000    0.000000
# 25%     11.100000    0.000000     0.000000   14.950000    0.000000
# 50%     13.500000    0.000000     0.000000   17.600000    0.000000
# 75%    270.650000    1.200000   377.000000  303.450000    0.200000
# max    327.400000    6.700000  1780.000000  326.000000    5.200000
#
#            Ppv2(W)       Ppv(W)   Vac(R)(V)  VacS(V)     VacT(V)  ...  \
# count   259.000000   259.000000  259.000000    259.0  259.000000  ...
# mean    147.915058   431.814672  232.239382      0.0  197.569498  ...
# std     317.547971   755.103394   33.145045      0.0    3.703177  ...
# min       0.000000     0.000000    0.000000      0.0  192.900000  ...
# 25%       0.000000     0.000000  232.800000      0.0  193.600000  ...
# 50%       0.000000     0.000000  235.900000      0.0  199.300000  ...
# 75%      89.000000   441.500000  241.100000      0.0  199.550000  ...
# max    1390.000000  2782.000000  255.400000      0.0  203.600000  ...
#
#        Eac_total(kWh)  T_total(H)  Bat_Volt(V)  Bat_Power(W)  Output_Volt(V)  \
# count      259.000000  259.000000   259.000000    259.000000      259.000000
# mean       332.289189  601.664093    53.127413     29.864865      232.487259
# std          3.399778    7.127242     0.947161    774.749227        5.762431
# min        328.700000  590.000000    52.100000  -2422.000000      214.500000
# 25%        329.400000  595.000000    52.400000      0.000000      228.800000
# 50%        331.000000  602.000000    52.600000     59.000000      231.800000
# 75%        335.000000  608.000000    53.700000    162.500000      236.950000
# max        338.700000  614.000000    57.200000   1976.000000      250.800000
#
#        Output_Freq(Hz)  Load_Power(W)  CHG_Temperature(℃)  Bat_Temperature(℃)  \
# count       259.000000     259.000000          259.000000          259.000000
# mean         49.989961     479.810811           41.672973           30.243243
# std           0.038069     479.980473            5.703178            2.060778
# min          49.900000      42.000000           34.400000           26.000000
# 25%          50.000000     138.500000           36.300000           28.000000
# 50%          50.000000     225.000000           42.700000           31.000000
# 75%          50.000000     941.000000           45.250000           32.000000
# max          50.100000    2615.000000           54.500000           33.000000
#
#        Bat_Percent(%)
# count      259.000000
# mean        70.335907
# std         20.965991
# min         46.000000
# 25%         50.000000
# 50%         63.000000
# 75%         98.000000
# max         98.000000
#
# [8 rows x 30 columns]

# %%
inverter_data['Time'] = pd.to_datetime(inverter_data['Time'], format='%Y-%m-%d %H:%M:%S') 
inverter_data.head()
# Out:
#                                      Time  Status  Vpv1(V)  Ipv1(A)  Ppv1(W)  \
# Alias / Serial number
# SD1740L010            2018-02-20 00:00:33  NORMAL     11.1      0.0        0
# SD1740L010            2018-02-20 00:05:33  NORMAL     11.1      0.0        0
# SD1740L010            2018-02-20 00:10:33  NORMAL     11.1      0.0        0
# SD1740L010            2018-02-20 00:15:33  NORMAL     11.1      0.0        0
# SD1740L010            2018-02-20 00:20:33  NORMAL     10.8      0.0        0
#
#                        Vpv2(V)  Ipv2(A)  Ppv2(W)  Ppv(W)  Vac(R)(V)  ...  \
# Alias / Serial number                                                ...
# SD1740L010                15.0      0.0        0       0      235.5  ...
# SD1740L010                15.0      0.0        0       0      237.1  ...
# SD1740L010                15.0      0.0        0       0      237.5  ...
# SD1740L010                15.1      0.0        0       0      239.1  ...
# SD1740L010                14.7      0.0        0       0      231.9  ...
#
#                        Eac_total(kWh)  T_total(H)  Bat_Volt(V)  Bat_Power(W)  \
# Alias / Serial number
# SD1740L010                      328.7         590         52.6            68
# SD1740L010                      328.8         590         52.6            82
# SD1740L010                      328.8         590         52.6            77
# SD1740L010                      328.8         590         52.6            80
# SD1740L010                      328.8         590         52.5           164
#
#                        Output_Volt(V)  Output_Freq(Hz)  Load_Power(W)  \
# Alias / Serial number
# SD1740L010                      231.3             50.0             67
# SD1740L010                      232.8             50.0             71
# SD1740L010                      233.3             50.0             48
# SD1740L010                      234.8             50.0             52
# SD1740L010                      227.7             50.0            170
#
#                        CHG_Temperature(℃)  Bat_Temperature(℃)  Bat_Percent(%)
# Alias / Serial number
# SD1740L010                           37.3                  30              54
# SD1740L010                           37.1                  30              54
# SD1740L010                           37.2                  30              54
# SD1740L010                           37.2                  30              54
# SD1740L010                           37.2                  30              54
#
# [5 rows x 32 columns]

# %%
time = [u'20/02/2018 00:00', u'20/02/2018 01:00', u'20/02/2018 01:00', u'20/02/2018 02:00', u'20/02/2018 03:00', u'20/02/2018 04:00', u'20/02/2018 04:00', u'20/02/2018 06:00', u'20/02/2018 06:30', u'20/02/2018 07:00', u'20/02/2018 07:00', u'20/02/2018 08:00', u'20/02/2018 09:00', u'20/02/2018 10:00', u'20/02/2018 10:00', u'20/02/2018 11:00', u'20/02/2018 12:00', u'20/02/2018 13:00', u'20/02/2018 13:00', u'20/02/2018 14:00', u'20/02/2018 15:00', u'20/02/2018 16:00', u'20/02/2018 16:00', u'20/02/2018 17:00', u'20/02/2018 17:30', u'20/02/2018 18:00', u'20/02/2018 19:00', u'20/02/2018 19:00', u'20/02/2018 20:00', u'20/02/2018 21:00', u'20/02/2018 22:00', u'20/02/2018 22:00', u'20/02/2018 23:00']
temp = [u'27.0', u'28', u'26.0', u'26.0', u'26.0', u'26', u'25.0', u'23.0', u'23.0', u'25', u'23.0', u'26.0', u'28.0', u'30', u'31.0', u'32.0', u'33.0', u'34', u'33.0', u'34.0', u'35.0', u'35', u'35.0', u'34.0', u'33.0', u'31.0', u'32', u'30.0', u'29.0', u'28.0', u'29', u'26.0', u'25.0']


humidity=[u'74', u'61', u'78', u'78', u'74', u'65', u'78', u'88', u'88', u'73', u'88', u'83', u'84', u'54', u'66', u'62', u'59', u'37', u'55', u'52', u'49', u'34', u'47', u'46', u'55', u'62', u'35', u'58', u'66', u'70', u'60', u'83', u'89']
windspeed=[u'5.6', u'0.0', u'0.0', u'5.6', u'5.6', u'0.0', u'5.6', u'3.7', u'3.7', u'0.0', u'0.0', u'3.7', u'11.1', u'9.3', u'9.3', u'9.3', u'11.1', u'9.3', u'5.6', u'5.6', u'7.4', u'7.4', u'3.7', u'3.7', u'0.0', u'0.0', u'0.0', u'0.0', u'0.0', u'0.0', u'0.0', u'0.0', u'0.0']
pressure=[u'1010', u'1010', u'1010', u'1010', u'1010', u'1010', u'1010', u'1011', u'1011', u'1011', u'1011', u'1012', u'1013', u'1012', u'1013', u'1012', u'1010', u'1008', u'1009', u'1008', u'1007', u'1006', u'1007', u'1007', u'1007', u'1007', u'1007', u'1008', u'1008', u'1009', u'1008', u'1009', u'1009']
conditions=[u'Mostly Cloudy', u'Scattered Clouds', u'Scattered Clouds', u'Scattered Clouds', u'Scattered Clouds', u'Partly Cloudy', u'Scattered Clouds', u'Scattered Clouds', u'Mostly Cloudy', u'Scattered Clouds', u'Mostly Cloudy', u'Mostly Cloudy', u'Unknown', u'Scattered Clouds', u'Partly Cloudy', u'Scattered Clouds', u'Scattered Clouds', u'Scattered Clouds', u'Scattered Clouds', u'Scattered Clouds', u'Partly Cloudy', u'Scattered Clouds', u'Partly Cloudy', u'Unknown', u'Unknown', u'Unknown', u'Clear', u'Unknown', u'Unknown', u'Unknown', u'Clear', u'Unknown', u'Unknown']

time_new = pd.to_datetime(time, format='%d/%m/%Y %H:%M')
time_new
# Out:
# DatetimeIndex(['2018-02-20 00:00:00', '2018-02-20 01:00:00',
#                '2018-02-20 01:00:00', '2018-02-20 02:00:00',
#                '2018-02-20 03:00:00', '2018-02-20 04:00:00',
#                '2018-02-20 04:00:00', '2018-02-20 06:00:00',
#                '2018-02-20 06:30:00', '2018-02-20 07:00:00',
#                '2018-02-20 07:00:00', '2018-02-20 08:00:00',
#                '2018-02-20 09:00:00', '2018-02-20 10:00:00',
#                '2018-02-20 10:00:00', '2018-02-20 11:00:00',
#                '2018-02-20 12:00:00', '2018-02-20 13:00:00',
#                '2018-02-20 13:00:00', '2018-02-20 14:00:00',
#                '2018-02-20 15:00:00', '2018-02-20 16:00:00',
#                '2018-02-20 16:00:00', '2018-02-20 17:00:00',
#                '2018-02-20 17:30:00', '2018-02-20 18:00:00',
#                '2018-02-20 19:00:00', '2018-02-20 19:00:00',
#                '2018-02-20 20:00:00', '2018-02-20 21:00:00',
#                '2018-02-20 22:00:00', '2018-02-20 22:00:00',
#                '2018-02-20 23:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
print(max(temp))
print(min(temp))
print(max(humidity))
print(min(humidity))
# Out:
# 35.0
# 23.0
# 89
# 34

# %%
trace5 = go.Scatter(
    x=time_new,
    y=humidity,
    name='Humidity',
    yaxis='y2'
)

trace9 = go.Scatter(
    x=time_new,
    y=temp,
    name='Temperature (C)',
    yaxis='y1',
    line = dict(
        width = 4)
)

# data = [trace5, trace6, trace7, trace8, trace9]
data = [trace5, trace9]
layout = go.Layout(
    xaxis=dict(
        title='time'
    ),
    yaxis=dict(
        title='Temperature (C)'
    ),
    yaxis2=dict(
        title='Humidity (%)',
        titlefont=dict(
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        
        overlaying='y',
        side='right'
    ),
    yaxis3=dict(
        title='Conditions',
        titlefont=dict(
        ),
        tickfont=dict(
            color='rgb(255, 0, 0)'
        ),
        overlaying='y',
        side='right'
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='test/test')
# Out:
# /Users/tpponmat/anaconda3/envs/dockerenv/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~TPponmat/58.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # 3. Inverter another day

# %%
inverter_data = pd.read_excel("SD1740L010 - 2018-02-07.xls", parse_dates = True, index_col = 0)
inverter_data.head()
inverter_data.describe().transpose()
# Out:
#                     count         mean          std     min      25%     50%  \
# Vpv1(V)             276.0   145.899638   126.350088    11.0   13.100  171.05
# Ipv1(A)             276.0     2.199275     2.897573     0.0    0.000    0.00
# Ppv1(W)             276.0   592.576087   770.632924     0.0    0.000    0.00
# Vpv2(V)             276.0   150.165580   122.882522    15.5   18.775  252.95
# Ipv2(A)             276.0     2.289855     2.975397     0.0    0.000    0.00
# Ppv2(W)             276.0   607.155797   776.527338     0.0    0.000    4.50
# Ppv(W)              276.0  1199.731884  1546.958445     0.0    0.000    4.50
# Vac(R)(V)           276.0   242.689130     6.186004   222.6  238.375  242.20
# VacS(V)             276.0     0.000000     0.000000     0.0    0.000    0.00
# VacT(V)             276.0   113.621014     1.418601   112.8  112.900  112.90
# Iac(R)(A)           276.0     5.700362     5.316680     0.4    1.000    3.30
# IacS(A)             276.0     0.000000     0.000000     0.0    0.000    0.00
# IacT(A)             276.0     0.000000     0.000000     0.0    0.000    0.00
# Fac(Hz)             276.0    49.984783     0.046557    49.9   50.000   50.00
# Pac(W)              276.0   866.423913  1403.450539 -2307.0  -86.250    6.00
# PacR(W)             276.0     0.000000     0.000000     0.0    0.000    0.00
# PacS(W)             276.0     0.000000     0.000000     0.0    0.000    0.00
# PacT(W)             276.0     0.000000     0.000000     0.0    0.000    0.00
# Temperature(℃)      276.0    37.937319     9.315131    25.4   28.550   37.65
# Eac_today(kWh)      276.0     7.650362     6.451359     0.1    3.800    4.75
# Eac_total(kWh)      276.0   205.790942    12.547047   191.1  191.100  206.65
# T_total(H)          276.0   295.217391     6.779905   283.0  290.000  295.00
# Bat_Volt(V)         276.0    57.198188     2.771209    51.9   58.400   58.80
# Bat_Power(W)        276.0   190.800725   460.587096   -14.0   -8.000   -2.00
# Output_Volt(V)      276.0   238.819928     6.460155   218.6  234.250  237.90
# Output_Freq(Hz)     276.0    49.985870     0.046511    49.9   50.000   50.00
# Load_Power(W)       276.0   477.416667   527.071577    35.0  132.750  302.50
# CHG_Temperature(℃)  276.0    37.389855     9.308263    25.0   28.050   36.95
# Bat_Temperature(℃)  276.0    21.735507     2.723428    17.0   19.000   22.00
# Bat_Percent(%)      276.0    91.326087    13.068582    58.0   98.000   98.00
#
#                          75%     max
# Vpv1(V)              266.425   328.6
# Ipv1(A)                4.950     7.7
# Ppv1(W)             1370.500  2003.0
# Vpv2(V)              264.125   310.8
# Ipv2(A)                5.125     7.9
# Ppv2(W)             1400.250  2013.0
# Ppv(W)              2770.750  4016.0
# Vac(R)(V)            247.825   254.8
# VacS(V)                0.000     0.0
# VacT(V)              112.900   117.2
# Iac(R)(A)             10.900    15.3
# IacS(A)                0.000     0.0
# IacT(A)                0.000     0.0
# Fac(Hz)               50.000    50.1
# Pac(W)              2186.250  3708.0
# PacR(W)                0.000     0.0
# PacS(W)                0.000     0.0
# PacT(W)                0.000     0.0
# Temperature(℃)        46.450    52.9
# Eac_today(kWh)         7.300    27.1
# Eac_total(kWh)       218.000   221.8
# T_total(H)           301.000   307.0
# Bat_Volt(V)           58.800    58.9
# Bat_Power(W)           0.000  2633.0
# Output_Volt(V)       244.350   251.6
# Output_Freq(Hz)       50.000    50.1
# Load_Power(W)        672.250  3091.0
# CHG_Temperature(℃)    46.100    52.4
# Bat_Temperature(℃)    25.000    25.0
# Bat_Percent(%)        98.000    98.0

# %%
inverter_data['Time'] = pd.to_datetime(inverter_data['Time'], format='%Y-%m-%d %H:%M:%S') 
data_to_use = inverter_data.copy()
inverter_data.head()
# Out:
#                                      Time  Status  Vpv1(V)  Ipv1(A)  Ppv1(W)  \
# Alias / Serial number
# SD1740L010            2018-02-07 00:03:12  NORMAL     13.0      0.0        0
# SD1740L010            2018-02-07 00:08:13  NORMAL     12.9      0.0        0
# SD1740L010            2018-02-07 00:13:13  NORMAL     13.0      0.0        0
# SD1740L010            2018-02-07 00:18:13  NORMAL     13.0      0.0        0
# SD1740L010            2018-02-07 00:23:13  NORMAL     13.1      0.0        0
#
#                        Vpv2(V)  Ipv2(A)  Ppv2(W)  Ppv(W)  Vac(R)(V)  ...  \
# Alias / Serial number                                                ...
# SD1740L010                18.7      0.0        0       0      243.5  ...
# SD1740L010                18.6      0.0        0       0      241.6  ...
# SD1740L010                18.7      0.0        0       0      242.6  ...
# SD1740L010                18.7      0.0        0       0      242.5  ...
# SD1740L010                18.7      0.0        0       0      242.3  ...
#
#                        Eac_total(kWh)  T_total(H)  Bat_Volt(V)  Bat_Power(W)  \
# Alias / Serial number
# SD1740L010                      191.1         283         58.7            -8
# SD1740L010                      191.1         283         58.8            -8
# SD1740L010                      191.1         283         58.7            -9
# SD1740L010                      191.1         283         58.8            -8
# SD1740L010                      191.1         283         58.7            -8
#
#                        Output_Volt(V)  Output_Freq(Hz)  Load_Power(W)  \
# Alias / Serial number
# SD1740L010                      239.1             50.1            155
# SD1740L010                      237.2             50.0            157
# SD1740L010                      238.2             50.0             80
# SD1740L010                      238.2             50.0             76
# SD1740L010                      237.9             50.0            174
#
#                        CHG_Temperature(℃)  Bat_Temperature(℃)  Bat_Percent(%)
# Alias / Serial number
# SD1740L010                           28.6                  21              98
# SD1740L010                           28.7                  21              98
# SD1740L010                           28.4                  21              98
# SD1740L010                           28.1                  21              98
# SD1740L010                           28.2                  21              98
#
# [5 rows x 32 columns]

# %%
trace5 = go.Scatter(
    x=data_to_use['Time'],
    y=data_to_use['Ppv(W)'],
    name='Ppv(W)',
    yaxis='y1'
)

trace6 = go.Scatter(
    x=data_to_use['Time'],
    y=-1*data_to_use['Pac(W)'],
    name='Pac(W)',
    yaxis='y1'
)

trace7 = go.Scatter(
    x=data_to_use['Time'],
    y=data_to_use['Load_Power(W)'],
    name='Load_Power(W)',
    yaxis='y1'
)

trace8 = go.Scatter(
    x=data_to_use['Time'],
    y=data_to_use['Bat_Power(W)'],
    name='Bat_Power(W)',
    yaxis='y1'
)

trace9 = go.Scatter(
    x=data_to_use['Time'],
    y=data_to_use['Eac_today(kWh)'],
    name='Eac_today(kWh)',
    yaxis='y2',
    line = dict(
        width = 4)
)

trace9 = go.Scatter(
    x=data_to_use['Time'],
    y=data_to_use['Bat_Percent(%)'],
    name='Bat_Percent(%)',
    yaxis='y2',
    line = dict(
        width = 4)
)

'''
['Time', 'Status', 'Vpv1(V)', 'Ipv1(A)', 'Ppv1(W)', 'Vpv2(V)', 'Ipv2(A)',
       'Ppv2(W)', 'Ppv(W)', 'Vac(R)(V)', 'VacS(V)', 'VacT(V)', 'Iac(R)(A)',
       'IacS(A)', 'IacT(A)', 'Fac(Hz)', 'Pac(W)', 'PacR(W)', 'PacS(W)',
       'PacT(W)', 'Temperature(℃)', 'Eac_today(kWh)', 'Eac_total(kWh)',
       'T_total(H)', 'Bat_Volt(V)', 'Bat_Power(W)', 'Output_Volt(V)',
       'Output_Freq(Hz)', 'Load_Power(W)', 'CHG_Temperature(℃)',
       'Bat_Temperature(℃)', 'Bat_Percent(%)']
'''

data = [trace5, trace6, trace7, trace8, trace9]
layout = go.Layout(
    xaxis=dict(
        title='time'
    ),
    yaxis=dict(
        title='Power (W)'
    ),
    yaxis2=dict(
        title='Battery %',
        titlefont=dict(
            color='rgb(148, 103, 189)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        
        overlaying='y',
        side='right'
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='test/test')
# Out:
# /Users/tpponmat/anaconda3/envs/dockerenv/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~TPponmat/60.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Weather

# %%
# http://api.wunderground.com/api/91cb5e6aefa48a31/history_20180220/q/TH/Ubon_Ratchathani.json

# %%
time = [u'20/02/2018 00:00', u'20/02/2018 01:00', u'20/02/2018 01:00', u'20/02/2018 02:00', u'20/02/2018 03:00', u'20/02/2018 04:00', u'20/02/2018 04:00', u'20/02/2018 06:00', u'20/02/2018 06:30', u'20/02/2018 07:00', u'20/02/2018 07:00', u'20/02/2018 08:00', u'20/02/2018 09:00', u'20/02/2018 10:00', u'20/02/2018 10:00', u'20/02/2018 11:00', u'20/02/2018 12:00', u'20/02/2018 13:00', u'20/02/2018 13:00', u'20/02/2018 14:00', u'20/02/2018 15:00', u'20/02/2018 16:00', u'20/02/2018 16:00', u'20/02/2018 17:00', u'20/02/2018 17:30', u'20/02/2018 18:00', u'20/02/2018 19:00', u'20/02/2018 19:00', u'20/02/2018 20:00', u'20/02/2018 21:00', u'20/02/2018 22:00', u'20/02/2018 22:00', u'20/02/2018 23:00']
temp = [u'27.0', u'28', u'26.0', u'26.0', u'26.0', u'26', u'25.0', u'23.0', u'23.0', u'25', u'23.0', u'26.0', u'28.0', u'30', u'31.0', u'32.0', u'33.0', u'34', u'33.0', u'34.0', u'35.0', u'35', u'35.0', u'34.0', u'33.0', u'31.0', u'32', u'30.0', u'29.0', u'28.0', u'29', u'26.0', u'25.0']
time_new = pd.to_datetime(time, format='%d/%m/%Y %H:%M')
time_new
# Out:
# DatetimeIndex(['2018-02-20 00:00:00', '2018-02-20 01:00:00',
#                '2018-02-20 01:00:00', '2018-02-20 02:00:00',
#                '2018-02-20 03:00:00', '2018-02-20 04:00:00',
#                '2018-02-20 04:00:00', '2018-02-20 06:00:00',
#                '2018-02-20 06:30:00', '2018-02-20 07:00:00',
#                '2018-02-20 07:00:00', '2018-02-20 08:00:00',
#                '2018-02-20 09:00:00', '2018-02-20 10:00:00',
#                '2018-02-20 10:00:00', '2018-02-20 11:00:00',
#                '2018-02-20 12:00:00', '2018-02-20 13:00:00',
#                '2018-02-20 13:00:00', '2018-02-20 14:00:00',
#                '2018-02-20 15:00:00', '2018-02-20 16:00:00',
#                '2018-02-20 16:00:00', '2018-02-20 17:00:00',
#                '2018-02-20 17:30:00', '2018-02-20 18:00:00',
#                '2018-02-20 19:00:00', '2018-02-20 19:00:00',
#                '2018-02-20 20:00:00', '2018-02-20 21:00:00',
#                '2018-02-20 22:00:00', '2018-02-20 22:00:00',
#                '2018-02-20 23:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
trace5 = go.Scatter(
    x=time_new,
    y=temp,
    name='Ppv(W)',
    yaxis='y1'
)

# trace6 = go.Scatter(
#     x=data_to_use['Time'],
#     y=-1*data_to_use['Pac(W)'],
#     name='Pac(W)',
#     yaxis='y1'
# )

data = [trace5]
layout = go.Layout(
    xaxis=dict(
        title='time'
    ),
    yaxis=dict(
        title='Outdoor Temp (C)'
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='test/test')
# Out:
# /Users/tpponmat/anaconda3/envs/dockerenv/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~TPponmat/64.embed" height="525px" width="100%"></iframe>
